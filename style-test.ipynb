# %%
import iv
import glob,os
import pandas as pd

# %%
DIR = "/Users/damoncrockett/Desktop/vegas-neon/vegas_neon/"

# %%
files = glob.glob(os.path.join(DIR,"*.jpg"))

# %%
df = pd.DataFrame({"local_path":files,"dummy":1})

# %%
iv.montage(df.local_path,df,'dummy',thumb=16)
# Out:
# <PIL.Image.Image image mode=RGB size=864x192 at 0x10145DA50>

# %%
import iv
import pandas as pd

# %%
df = pd.read_csv("test.csv")

# %%
iv.attach(df,'local_path')

# %%
iv.amontage(featcol='Hue_Median',thumb=20)
# Out:
# <PIL.Image.Image image mode=RGB size=860x380 at 0x113498B10>

# %%
import sys
sys.path.append("../src")

# %%
from ivpy import show,montage,histogram,scatter,attach

# %%
import glob,os
import pandas as pd

# %%
DIR = "/Volumes/LaCie6TBRAID/YCBA/ycba_image_download/images/"

# %%
impaths = glob.glob(os.path.join(DIR,"*.jpg"))

# %%
df = pd.DataFrame({"local_path":impaths})

# %%
attach(df,'local_path')

# %%
# %timeit montage(sample=100,thumb=16)
# Out:
# 1 loop, best of 3: 4.44 s per loop

# %%
# %timeit show(sample=100,thumb=16)
# Out:
# 1 loop, best of 3: 4.81 s per loop

# %%
show(600,thumb=64)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=64x45 at 0x1094AAFD0>

# %%
len(df)
# Out:
# 31262

# %%
montage(sample=500,thumb=32,shape='circle')
# Out:
# <PIL.Image.Image image mode=RGB size=864x864 at 0x108488A90>

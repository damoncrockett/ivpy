# %%
import sys
sys.path.append("../src")

# %%
from ivpy import attach,detach,show,montage,histogram,scatter
import pandas as pd

# %%
df = pd.read_csv("../datasets/vG.csv")

# %%
attach(df,'local_path')

# %%
df.columns
# Out:
# Index([u'Filename', u'Year_Month', u'Brightness_Median', u'Saturation_Median',
#        u'Label_Place', u'Year', u'Month', u'Title', u'Brightness_Stdev',
#        u'Saturation_Stdev', u'Hue_Median', u'Hue_Stdev', u'Shape_Count',
#        u'Shape_Avg Size', u'Shape_Area_Fraction', u'Image_Width ',
#        u'Image_Height ', u'Proportion', u'Genre_LM', u'local_path'],
#       dtype='object')

# %%
montage(featcol='Brightness_Median',sample=200,idx=True,thumb=16,ascending=True)
# Out:
# <PIL.Image.Image image mode=RGB size=976x64 at 0x107EFA750>

# %%
histogram('Saturation_Median',ycol='Brightness_Median',quantile=True,ascending=True,thumb=20,idx=True)
# Out:
# <PIL.Image.Image image mode=RGB size=700x620 at 0x107894C50>

# %%
scatter('Saturation_Median','Brightness_Median',thumb=24,side=980,idx=True)
# Out:
# <PIL.Image.Image image mode=RGB size=980x980 at 0x1078B7BD0>

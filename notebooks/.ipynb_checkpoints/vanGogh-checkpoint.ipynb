# %%
import sys
sys.path.append("../src")

# %%
from ivpy import attach,detach,show,montage,histogram,scatter
import pandas as pd

# %%
df = pd.read_csv("../datasets/vG.csv")

# %%
attach(df,'local_path')

# %%
df.columns
# Out:
# Index([u'Filename', u'Year_Month', u'Brightness_Median', u'Saturation_Median',
#        u'Label_Place', u'Year', u'Month', u'Title', u'Brightness_Stdev',
#        u'Saturation_Stdev', u'Hue_Median', u'Hue_Stdev', u'Shape_Count',
#        u'Shape_Avg Size', u'Shape_Area_Fraction', u'Image_Width ',
#        u'Image_Height ', u'Proportion', u'Genre_LM', u'local_path'],
#       dtype='object')

# %%
montage(featcol='Brightness_Median',sample=200,thumb=32,idx=True,ascending=True)
# Out:
# <PIL.Image.Image image mode=RGB size=960x224 at 0x109029210>

# %%
histogram('Saturation_Median',ycol='Brightness_Median',quantile=True,ascending=True,idx=True)
# Out:
# <PIL.Image.Image image mode=RGB size=980x868 at 0x109029650>

# %%
scatter('Year_Month','Brightness_Median',thumb=24,side=980)
# Out:
# <PIL.Image.Image image mode=RGB size=980x980 at 0x10900E810>
